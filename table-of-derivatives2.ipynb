# %%
import sympy as sp

# Define symbolic variables
x, t = sp.symbols('x, t')

# Define your function (e.g., sin(x) * e^x)
f = sp.sin(x) * sp.exp(x)

# Compute the derivative
df = sp.diff(f, x)

# Display the result beautifully
sp.init_printing()
df
# Out:
#  x           x
# ℯ ⋅sin(x) + ℯ ⋅cos(x)

# %%
# Define your function
f = sp.cos(x)

# Compute the derivative
df1 = sp.diff(f, x)

df1
# Out:
# -sin(x)

# %%
f2 = sp.exp(8 * x)
df2 = sp.diff(f2, x)

df2
# Out:
#    8⋅x
# 8⋅ℯ

# %%
f3 = sp.exp(x)
df3 = sp.diff(f3, x)

df3
# Out:
#  x
# ℯ

# %%
f4 = sp.ln(x)
df4 = sp.diff(f4, x)

df4
# Out:
# 1
# ─
# x

# %%
#f5 = sp.exp(4)
df5 = sp.diff(sp.exp(4))

df5
# Out:
# 0

# %%
f6 = sp.exp(8 * t)
df6 = sp.diff(f6, t)

df6
# Out:
#    8⋅t
# 8⋅ℯ

# %%
f7 = sp.exp(-3 * x)
df7 = sp.diff(f7, x)

df7
# Out:
#     -3⋅x
# -3⋅ℯ

# %%
f8 = sp.sin(3 * x)
df8 = sp.diff(f8, x)

df8
# Out:
# 3⋅cos(3⋅x)

# %%
f9 = sp.cos(4 * x)
df9 = sp.diff(f9, x)

df9
# Out:
# -4⋅sin(4⋅x)

# %%
f10 = sp.tan(6 * x)
df10 = sp.diff(f10, x)

df10
# Out:
#      2
# 6⋅tan (6⋅x) + 6

# %%
f11 = sp.exp(3 * t) - sp.cos(7 * t)
df11 = sp.diff(f11, t)

df11
# Out:
#    3⋅t
# 3⋅ℯ    + 7⋅sin(7⋅t)

# %%
f12 = sp.ln(5 * x) - sp.exp(-7 * x)
df12 = sp.diff(f12, x)

df12
# Out:
#    -7⋅x   1
# 7⋅ℯ     + ─
#           x
