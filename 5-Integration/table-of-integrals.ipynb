# %%
import sympy as sp
import scipy as si

# Define symbolic variables
x, t = sp.symbols('x, t')

# Define your function (e.g., sin(x) * e^x)
f = sp.sin(x) * sp.exp(x)

# Compute the integrate
df = sp.integrate(f, x)

# Display the result beautifully
sp.init_printing()
df
# Out:
#  x           x
# ℯ ⋅sin(x)   ℯ ⋅cos(x)
# ───────── - ─────────
#     2           2

# %%
# Define your function
f = sp.cos(x)

# Compute the integrate
df1 = sp.integrate(f, x)

df1
# Out:
# sin(x)

# %%
f2 = sp.exp(8 * x)
df2 = sp.integrate(f2, x)

df2
# Out:
#  8⋅x
# ℯ
# ────
#  8

# %%
f2 = sp.exp(8 * x)
df2 = sp.integrate(f2, x)

df2
# Out:
#  8⋅x
# ℯ
# ────
#  8

# %%
f3 = sp.tan(x)
df3 = sp.integrate(f3, x)

df3
# Out:
# -log(cos(x))

# %%
f4 = sp.sin(x)
df4 = sp.integrate(f4, x)
df4
# Out:
# -cos(x)

# %%
f5 = sp.sec(x)
df5 = sp.integrate(f5, x)
df5
# Out:
#   log(sin(x) - 1)   log(sin(x) + 1)
# - ─────────────── + ───────────────
#          2                 2

# %%
f6 = sp.sech(x)
df6 = sp.integrate(f6, x)
df6
# Out:
#       ⎛    ⎛x⎞⎞
# 2⋅atan⎜tanh⎜─⎟⎟
#       ⎝    ⎝2⎠⎠

# %%
f7 = sp.cosh(x)
df7 = sp.integrate(f7, x)
df7
# Out:
# sinh(x)
