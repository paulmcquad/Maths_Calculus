# %%
import sympy as sp
import scipy as si

# Define symbolic variables
x, t = sp.symbols('x, t')

# Define your function (e.g., sin(x) * e^x)
sp.integrate((x**3-6*x**2+x+1), x)

# Display the result beautifully
sp.init_printing()

# %% [markdown]
# $$ x^3-6(x)^2+x+1 $$

# %%
sp.integrate((x**3-6*x**2+x+1), x)
# Out:
#  4           2
# x       3   x
# ── - 2⋅x  + ── + x
# 4           2

# %%
sp.diff(x**3-6*x**2+x+1)
# Out:
#    2
# 3⋅x  - 12⋅x + 1
