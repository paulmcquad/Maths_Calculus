# %%
# import fourier_transform
from sympy import fourier_transform, exp
from sympy.abc import x, k

# Using fourier_transform() method
gfg = fourier_transform(exp(-x**2), x, k)

gfg
# Out:
# sqrt(pi)*exp(-pi**2*k**2)

# %%
# import fourier_transform
from sympy import fourier_transform, exp
from sympy.abc import x, k

# Using fourier_transform() method
gfg = fourier_transform(exp(-x**2), x, 4)

gfg
# Out:
# sqrt(pi)*exp(-16*pi**2)

# %%
# import fourier_transform
from sympy import fourier_transform, sin
from sympy.abc import x, k

# Using fourier_transform() method
gfg = fourier_transform(sin(x), x, 4)

gfg
# Out:
# FourierTransform(sin(x), x, 4)
